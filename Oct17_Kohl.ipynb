# %% [markdown]
# <a href="https://colab.research.google.com/github/BelenKohl/SRMP/blob/main/Oct17_Kohl.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

# %%
# !git clone https://github.com/BelenKohl/SRMP.git
# Out:
# fatal: destination path 'SRMP' already exists and is not an empty directory.

# %%
import pandas as pd

# %%
df = pd.read_csv('./gaia.csv')

# %%
import matplotlib.pyplot as plt

# %%
plt.plot (df['bp_rp'],df['abs_G'],'.')
plt.gca().invert_yaxis()

# %%
# !git clone https://github.com/BelenKohl/SRMP.git
# Out:
# fatal: destination path 'SRMP' already exists and is not an empty directory.
