# %% [markdown]
# <a href="https://colab.research.google.com/github/BelenKohl/SRMP/blob/main/Nov28_kohl.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/BelenKohl/SRMP.git
# Out:
# Cloning into 'SRMP'...
# remote: Enumerating objects: 33, done.
# remote: Counting objects: 100% (33/33), done.
# remote: Compressing objects: 100% (31/31), done.
# remote: Total 33 (delta 11), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (33/33), 233.30 KiB | 1.23 MiB/s, done.
# Resolving deltas: 100% (11/11), done.

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df=pd.read_csv('Gaia_Prot_cmatch.csv')

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(df['Prot'],df['astrometric_params_solved'],',')
plt.yscale('log')

# %%
plt.plot(df['Prot'],df['b'],',')
plt.xscale('log')

# %%
plt.plot(df['Prot'],df['bp_g'],',')
plt.yscale('log')

# %%
plt.plot(df['Prot'],df['bp_rp'],',')
plt.yscale('log')

# %%
plt.plot(df['Prot'],df['dec'],',')

# %%
plt.plot(df['Prot'],df['dec_error'],',')

# %%
plt.plot(df['Prot'],df['dec_parallax_corr'],',')
plt.yscale('log')

# %%
plt.plot(df['Prot'],df['dec_pmdec_corr'],',')

# %%
plt.plot(df['Prot'],df['dec_pmra_corr'],',')

# %%
plt.plot(df['Prot'],df['dr2_rv_nb_transits'],',')
