# %% [markdown]
# <a href="https://colab.research.google.com/github/BelenKohl/SRMP/blob/main/Nov28_kohl.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/BelenKohl/SRMP.git
# Out:
# Cloning into 'SRMP'...
# remote: Enumerating objects: 30, done.
# remote: Counting objects: 100% (30/30), done.
# remote: Compressing objects: 100% (28/28), done.
# remote: Total 30 (delta 9), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (30/30), 198.64 KiB | 1.00 MiB/s, done.
# Resolving deltas: 100% (9/9), done.

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df=pd.read_csv('Gaia_Prot_cmatch.csv')
# Out:
# <ipython-input-5-2bffda7b3f7e>:1: DtypeWarning: Columns (39,67) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('Gaia_Prot_cmatch.csv')

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(df['Prot'],df['astrometric_params_solved'],',')
plt.yscale('log')

# %%
plt.plot(df['Prot'],df['b'],',')
plt.xscale('log')
